# %% [markdown]
# # Introduction
# In this notebook, I will build a model using random forest and predict house prices with the data given.<br>
# And I improve the accuracy using a feature selection method where I'll test each newly added feature to see if the MAE increased or decreased.

# %% [markdown]
# # Importing Data and Necessary Libraries

# %%
# This Python 3 environment comes with many helpful analytics libraries installed
# It is defined by the kaggle/python Docker image: https://github.com/kaggle/docker-python
# For example, here's several helpful packages to load

import numpy as np # linear algebra
import pandas as pd # data processing, CSV file I/O (e.g. pd.read_csv)

from sklearn.ensemble import RandomForestRegressor # The model to be used
from sklearn.metrics import mean_absolute_error # Calculating accuracy
from sklearn.model_selection import train_test_split # Improve training for the model

data_path = '/kaggle/input/home-data-for-ml-course/train.csv' 
home_data = pd.read_csv(data_path)

# %% [markdown]
# ## Preprocessing
# Here we make a variable that contains all the columns except the SalePrice since that will obstruct training.

# %%
home_data = home_data.loc[:, home_data.columns != 'Id'] # This is to remove the Id column which will be useless for training
home_data = pd.get_dummies(home_data) # This will turn any string values into a true and false columns
home_data = home_data.fillna(0) # Replace NaN values with 0

X = home_data.drop(columns=["SalePrice"])
y = home_data["SalePrice"]
original_features = home_data.loc[:, home_data.columns != 'SalePrice']


print(f"original features shape: {home_data.shape}")
print(f"number of features: {len(original_features)}")
print(home_data.head())
# Out:
# original features shape: (1460, 288)
# number of features: 1460
#    MSSubClass  LotFrontage  LotArea  OverallQual  OverallCond  YearBuilt  \
# 0          60         65.0     8450            7            5       2003
# 1          20         80.0     9600            6            8       1976
# 2          60         68.0    11250            7            5       2001
# 3          70         60.0     9550            7            5       1915
# 4          60         84.0    14260            8            5       2000
#
#    YearRemodAdd  MasVnrArea  BsmtFinSF1  BsmtFinSF2  ...  SaleType_ConLw  \
# 0          2003       196.0         706           0  ...           False
# 1          1976         0.0         978           0  ...           False
# 2          2002       162.0         486           0  ...           False
# 3          1970         0.0         216           0  ...           False
# 4          2000       350.0         655           0  ...           False
#
#    SaleType_New  SaleType_Oth  SaleType_WD  SaleCondition_Abnorml  \
# 0         False         False         True                  False
# 1         False         False         True                  False
# 2         False         False         True                  False
# 3         False         False         True                   True
# 4         False         False         True                  False
#
#    SaleCondition_AdjLand  SaleCondition_Alloca  SaleCondition_Family  \
# 0                  False                 False                 False
# 1                  False                 False                 False
# 2                  False                 False                 False
# 3                  False                 False                 False
# 4                  False                 False                 False
#
#    SaleCondition_Normal  SaleCondition_Partial
# 0                  True                  False
# 1                  True                  False
# 2                  True                  False
# 3                 False                  False
# 4                  True                  False
#
# [5 rows x 288 columns]

# %% [markdown]
# # Feature Selection
# The most important part of this notebook is feature selection where we will discard any features that doesn't improve the mean absolute error.<br>
# ## Step 1: Create the feature selection function
# we create the feature_selection function that will take as input the features, training data, Sale price training data, testing data, and finally the validation testing data. <br>
# Then, initialize the ML model and give it the training data, to then make predictions and test the mean absolute error (and print for debugging).<br>
# And return the **MAE**.

# %%
model = None
def feature_selection(features, feature_train, feature_val, output_train, output_val):
    global model
    model = RandomForestRegressor(random_state=1) # Current ML model
    model.fit(feature_train[features], output_train) # Train the model with the training data

    predictions = model.predict(feature_val[features]) # Make the predictions
    mae = mean_absolute_error(output_val, predictions) # Calculate the Mean absolute error

    return mae

# %% [markdown]
# ## Step 2: Start selection
# Now that we have the function, we will begin selecting features one by one and test which one improved our **MAE**.<br>To do that, I will make a loop that:
# 1. Add new feature.
# 2. Create test and validation data with the new feature.
# 3. Add the data to the function feature_selection.
# 4. Check whether **MAE** improved or not.
# 5. If so, keep the feature, else discard it.

# %%
previous_mae = 0
selected_features = []
train_X, val_X, train_y, val_y = train_test_split(X, y, random_state=1) # Create training data and validation data

for feature in original_features:
    if feature not in selected_features: # We append a new feature to a list to test the new MAE
        selected_features.append(feature)

        mae = feature_selection(selected_features, train_X, val_X, train_y, val_y)
        if not previous_mae: previous_mae = mae

        if min(mae, previous_mae) == mae:
            print(f"KEPT {feature}: MAE = {mae:.2f}")
            previous_mae = mae
        else:
            print(f"REMOVED {feature}")
            selected_features.remove(feature)
# Out:
# KEPT MSSubClass: MAE = 48346.44
# KEPT LotFrontage: MAE = 47086.63
# KEPT LotArea: MAE = 44642.28
# KEPT OverallQual: MAE = 27946.33
# KEPT OverallCond: MAE = 27063.86
# KEPT YearBuilt: MAE = 25085.10
# KEPT YearRemodAdd: MAE = 24779.62
# KEPT MasVnrArea: MAE = 23533.29
# KEPT BsmtFinSF1: MAE = 21743.72
# KEPT BsmtFinSF2: MAE = 21663.38
# KEPT BsmtUnfSF: MAE = 21081.83
# KEPT TotalBsmtSF: MAE = 20258.85
# KEPT 1stFlrSF: MAE = 19609.53
# KEPT 2ndFlrSF: MAE = 18080.86
# KEPT LowQualFinSF: MAE = 17861.74
# KEPT GrLivArea: MAE = 16816.85
# KEPT BsmtFullBath: MAE = 16813.47
# REMOVED BsmtHalfBath
# KEPT FullBath: MAE = 16757.18
# REMOVED HalfBath
# REMOVED BedroomAbvGr
# REMOVED KitchenAbvGr
# REMOVED TotRmsAbvGrd
# KEPT Fireplaces: MAE = 16624.27
# KEPT GarageYrBlt: MAE = 16208.60
# KEPT GarageCars: MAE = 16093.88
# REMOVED GarageArea
# KEPT WoodDeckSF: MAE = 16064.51
# REMOVED OpenPorchSF
# REMOVED EnclosedPorch
# REMOVED 3SsnPorch
# REMOVED ScreenPorch
# REMOVED PoolArea
# REMOVED MiscVal
# REMOVED MoSold
# KEPT YrSold: MAE = 16054.22
# REMOVED MSZoning_C (all)
# REMOVED MSZoning_FV
# REMOVED MSZoning_RH
# REMOVED MSZoning_RL
# REMOVED MSZoning_RM
# REMOVED Street_Grvl
# REMOVED Street_Pave
# KEPT Alley_Grvl: MAE = 16008.18
# REMOVED Alley_Pave
# REMOVED LotShape_IR1
# REMOVED LotShape_IR2
# REMOVED LotShape_IR3
# REMOVED LotShape_Reg
# REMOVED LandContour_Bnk
# REMOVED LandContour_HLS
# KEPT LandContour_Low: MAE = 16001.31
# REMOVED LandContour_Lvl
# REMOVED Utilities_AllPub
# REMOVED Utilities_NoSeWa
# REMOVED LotConfig_Corner
# REMOVED LotConfig_CulDSac
# REMOVED LotConfig_FR2
# REMOVED LotConfig_FR3
# REMOVED LotConfig_Inside
# REMOVED LandSlope_Gtl
# REMOVED LandSlope_Mod
# REMOVED LandSlope_Sev
# REMOVED Neighborhood_Blmngtn
# REMOVED Neighborhood_Blueste
# REMOVED Neighborhood_BrDale
# REMOVED Neighborhood_BrkSide
# REMOVED Neighborhood_ClearCr
# REMOVED Neighborhood_CollgCr
# REMOVED Neighborhood_Crawfor
# REMOVED Neighborhood_Edwards
# REMOVED Neighborhood_Gilbert
# REMOVED Neighborhood_IDOTRR
# REMOVED Neighborhood_MeadowV
# REMOVED Neighborhood_Mitchel
# REMOVED Neighborhood_NAmes
# REMOVED Neighborhood_NPkVill
# REMOVED Neighborhood_NWAmes
# REMOVED Neighborhood_NoRidge
# REMOVED Neighborhood_NridgHt
# REMOVED Neighborhood_OldTown
# REMOVED Neighborhood_SWISU
# KEPT Neighborhood_Sawyer: MAE = 15966.70
# REMOVED Neighborhood_SawyerW
# REMOVED Neighborhood_Somerst
# REMOVED Neighborhood_StoneBr
# REMOVED Neighborhood_Timber
# REMOVED Neighborhood_Veenker
# REMOVED Condition1_Artery
# KEPT Condition1_Feedr: MAE = 15956.65
# REMOVED Condition1_Norm
# REMOVED Condition1_PosA
# REMOVED Condition1_PosN
# REMOVED Condition1_RRAe
# REMOVED Condition1_RRAn
# REMOVED Condition1_RRNe
# REMOVED Condition1_RRNn
# REMOVED Condition2_Artery
# REMOVED Condition2_Feedr
# REMOVED Condition2_Norm
# REMOVED Condition2_PosA
# KEPT Condition2_PosN: MAE = 15883.05
# REMOVED Condition2_RRAe
# REMOVED Condition2_RRAn
# REMOVED Condition2_RRNn
# REMOVED BldgType_1Fam
# REMOVED BldgType_2fmCon
# REMOVED BldgType_Duplex
# REMOVED BldgType_Twnhs
# REMOVED BldgType_TwnhsE
# REMOVED HouseStyle_1.5Fin
# REMOVED HouseStyle_1.5Unf
# REMOVED HouseStyle_1Story
# REMOVED HouseStyle_2.5Fin
# REMOVED HouseStyle_2.5Unf
# REMOVED HouseStyle_2Story
# REMOVED HouseStyle_SFoyer
# REMOVED HouseStyle_SLvl
# REMOVED RoofStyle_Flat
# REMOVED RoofStyle_Gable
# REMOVED RoofStyle_Gambrel
# REMOVED RoofStyle_Hip
# REMOVED RoofStyle_Mansard
# REMOVED RoofStyle_Shed
# REMOVED RoofMatl_ClyTile
# REMOVED RoofMatl_CompShg
# REMOVED RoofMatl_Membran
# REMOVED RoofMatl_Metal
# REMOVED RoofMatl_Roll
# REMOVED RoofMatl_Tar&Grv
# REMOVED RoofMatl_WdShake
# REMOVED RoofMatl_WdShngl
# REMOVED Exterior1st_AsbShng
# REMOVED Exterior1st_AsphShn
# REMOVED Exterior1st_BrkComm
# REMOVED Exterior1st_BrkFace
# REMOVED Exterior1st_CBlock
# REMOVED Exterior1st_CemntBd
# REMOVED Exterior1st_HdBoard
# REMOVED Exterior1st_ImStucc
# REMOVED Exterior1st_MetalSd
# REMOVED Exterior1st_Plywood
# REMOVED Exterior1st_Stone
# REMOVED Exterior1st_Stucco
# REMOVED Exterior1st_VinylSd
# REMOVED Exterior1st_Wd Sdng
# REMOVED Exterior1st_WdShing
# REMOVED Exterior2nd_AsbShng
# REMOVED Exterior2nd_AsphShn
# REMOVED Exterior2nd_Brk Cmn
# REMOVED Exterior2nd_BrkFace
# REMOVED Exterior2nd_CBlock
# REMOVED Exterior2nd_CmentBd
# REMOVED Exterior2nd_HdBoard
# REMOVED Exterior2nd_ImStucc
# REMOVED Exterior2nd_MetalSd
# REMOVED Exterior2nd_Other
# REMOVED Exterior2nd_Plywood
# REMOVED Exterior2nd_Stone
# REMOVED Exterior2nd_Stucco
# REMOVED Exterior2nd_VinylSd
# REMOVED Exterior2nd_Wd Sdng
# REMOVED Exterior2nd_Wd Shng
# REMOVED MasVnrType_BrkCmn
# REMOVED MasVnrType_BrkFace
# REMOVED MasVnrType_Stone
# REMOVED ExterQual_Ex
# REMOVED ExterQual_Fa
# REMOVED ExterQual_Gd
# REMOVED ExterQual_TA
# REMOVED ExterCond_Ex
# REMOVED ExterCond_Fa
# REMOVED ExterCond_Gd
# REMOVED ExterCond_Po
# REMOVED ExterCond_TA
# REMOVED Foundation_BrkTil
# REMOVED Foundation_CBlock
# REMOVED Foundation_PConc
# REMOVED Foundation_Slab
# REMOVED Foundation_Stone
# REMOVED Foundation_Wood
# REMOVED BsmtQual_Ex
# REMOVED BsmtQual_Fa
# REMOVED BsmtQual_Gd
# REMOVED BsmtQual_TA
# REMOVED BsmtCond_Fa
# REMOVED BsmtCond_Gd
# REMOVED BsmtCond_Po
# REMOVED BsmtCond_TA
# REMOVED BsmtExposure_Av
# REMOVED BsmtExposure_Gd
# REMOVED BsmtExposure_Mn
# REMOVED BsmtExposure_No
# REMOVED BsmtFinType1_ALQ
# REMOVED BsmtFinType1_BLQ
# REMOVED BsmtFinType1_GLQ
# REMOVED BsmtFinType1_LwQ
# REMOVED BsmtFinType1_Rec
# REMOVED BsmtFinType1_Unf
# REMOVED BsmtFinType2_ALQ
# REMOVED BsmtFinType2_BLQ
# REMOVED BsmtFinType2_GLQ
# REMOVED BsmtFinType2_LwQ
# REMOVED BsmtFinType2_Rec
# REMOVED BsmtFinType2_Unf
# REMOVED Heating_Floor
# REMOVED Heating_GasA
# REMOVED Heating_GasW
# REMOVED Heating_Grav
# REMOVED Heating_OthW
# REMOVED Heating_Wall
# REMOVED HeatingQC_Ex
# REMOVED HeatingQC_Fa
# REMOVED HeatingQC_Gd
# REMOVED HeatingQC_Po
# REMOVED HeatingQC_TA
# REMOVED CentralAir_N
# REMOVED CentralAir_Y
# REMOVED Electrical_FuseA
# REMOVED Electrical_FuseF
# REMOVED Electrical_FuseP
# REMOVED Electrical_Mix
# REMOVED Electrical_SBrkr
# REMOVED KitchenQual_Ex
# REMOVED KitchenQual_Fa
# REMOVED KitchenQual_Gd
# REMOVED KitchenQual_TA
# REMOVED Functional_Maj1
# REMOVED Functional_Maj2
# REMOVED Functional_Min1
# REMOVED Functional_Min2
# REMOVED Functional_Mod
# REMOVED Functional_Sev
# REMOVED Functional_Typ
# REMOVED FireplaceQu_Ex
# REMOVED FireplaceQu_Fa
# REMOVED FireplaceQu_Gd
# REMOVED FireplaceQu_Po
# REMOVED FireplaceQu_TA
# REMOVED GarageType_2Types
# REMOVED GarageType_Attchd
# REMOVED GarageType_Basment
# REMOVED GarageType_BuiltIn
# REMOVED GarageType_CarPort
# REMOVED GarageType_Detchd
# REMOVED GarageFinish_Fin
# REMOVED GarageFinish_RFn
# REMOVED GarageFinish_Unf
# REMOVED GarageQual_Ex
# REMOVED GarageQual_Fa
# REMOVED GarageQual_Gd
# REMOVED GarageQual_Po
# REMOVED GarageQual_TA
# REMOVED GarageCond_Ex
# REMOVED GarageCond_Fa
# REMOVED GarageCond_Gd
# REMOVED GarageCond_Po
# REMOVED GarageCond_TA
# REMOVED PavedDrive_N
# REMOVED PavedDrive_P
# REMOVED PavedDrive_Y
# REMOVED PoolQC_Ex
# REMOVED PoolQC_Fa
# REMOVED PoolQC_Gd
# REMOVED Fence_GdPrv
# REMOVED Fence_GdWo
# REMOVED Fence_MnPrv
# REMOVED Fence_MnWw
# REMOVED MiscFeature_Gar2
# REMOVED MiscFeature_Othr
# REMOVED MiscFeature_Shed
# REMOVED MiscFeature_TenC
# REMOVED SaleType_COD
# REMOVED SaleType_CWD
# REMOVED SaleType_Con
# REMOVED SaleType_ConLD
# REMOVED SaleType_ConLI
# REMOVED SaleType_ConLw
# REMOVED SaleType_New
# REMOVED SaleType_Oth
# REMOVED SaleType_WD
# REMOVED SaleCondition_Abnorml
# REMOVED SaleCondition_AdjLand
# REMOVED SaleCondition_Alloca
# REMOVED SaleCondition_Family
# REMOVED SaleCondition_Normal
# REMOVED SaleCondition_Partial

# %% [markdown]
# ## Step 3: Test the model
# Finally, we will test the model using the test.csv.

# %%
train_feature_names = model.feature_names_in_
test_data = pd.read_csv('/kaggle/input/home-data-for-ml-course/test.csv')

test_data_processed = test_data.drop(columns=['Id'])
test_data_processed = pd.get_dummies(test_data_processed)
test_data_processed = test_data_processed.fillna(0)

test_X = test_data_processed.reindex(columns=train_feature_names, fill_value=0)

preds = model.predict(test_X)

# %% [markdown]
# ## Step 4: Create the submission file

# %%
output = pd.DataFrame({'Id': test_data.Id,
                       'SalePrice': preds})
output.to_csv('submission.csv', index=False)

# %% [markdown]
# # My Thoughts
# I improved the MAE from the tutorial in kaggle, and I'm proud of the results. Still I noticed that despite this working correctly, I dropped many features that could have some use, maybe if they are tied together we could get a different prediction.<br>
# I noticed the neighborhood column for example that could serve in the predictions but got dropped instead since the MAE got higher, so there should be a better method. But that's the limit of my current knowledge.
