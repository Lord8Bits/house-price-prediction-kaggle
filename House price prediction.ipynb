# %% [raw]
# I will start first by importing all the necessary libraries and that includes: numpy, pandas, and of course scikit-learn. And initializing all the necessary data and selected features.

# %%
import pandas as pd
import numpy as np
from sklearn.ensemble import RandomForestRegressor
from sklearn.metrics import mean_absolute_error
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import LabelEncoder

data_path = 'input/home-data-for-ml-course/train.csv'
home_data = pd.read_csv(data_path)
home_data = pd.get_dummies(home_data)

original_features = home_data.columns
print(f"Original features shape: {home_data.shape}")
print(f"Number of features: {len(original_features)}")
print(home_data.head())
# Out:
# Original features shape: (1460, 289)
# Number of features: 289
#    Id  MSSubClass  LotFrontage  LotArea  OverallQual  OverallCond  YearBuilt  \
# 0   1          60         65.0     8450            7            5       2003
# 1   2          20         80.0     9600            6            8       1976
# 2   3          60         68.0    11250            7            5       2001
# 3   4          70         60.0     9550            7            5       1915
# 4   5          60         84.0    14260            8            5       2000
#
#    YearRemodAdd  MasVnrArea  BsmtFinSF1  ...  SaleType_ConLw  SaleType_New  \
# 0          2003       196.0         706  ...           False         False
# 1          1976         0.0         978  ...           False         False
# 2          2002       162.0         486  ...           False         False
# 3          1970         0.0         216  ...           False         False
# 4          2000       350.0         655  ...           False         False
#
#    SaleType_Oth  SaleType_WD  SaleCondition_Abnorml  SaleCondition_AdjLand  \
# 0         False         True                  False                  False
# 1         False         True                  False                  False
# 2         False         True                  False                  False
# 3         False         True                   True                  False
# 4         False         True                  False                  False
#
#    SaleCondition_Alloca  SaleCondition_Family  SaleCondition_Normal  \
# 0                 False                 False                  True
# 1                 False                 False                  True
# 2                 False                 False                  True
# 3                 False                 False                 False
# 4                 False                 False                  True
#
#    SaleCondition_Partial
# 0                  False
# 1                  False
# 2                  False
# 3                  False
# 4                  False
#
# [5 rows x 289 columns]

# %%
selected_features = []
y = home_data.SalePrice # Sale prices
home_model = RandomForestRegressor(random_state=1) # Current ML model
previous_mae = 1
for feature in original_features:
    if feature not in selected_features: # We append a new feature to a list to test the new MAE
        selected_features.append(feature)
        X = home_data[selected_features]
        train_X, val_X, train_y, val_y = train_test_split(X, y, random_state=1) # Create training data and validation data
        home_data = pd.get_dummies(home_data) # Convert any string values into numerical data
        home_model.fit(train_X, train_y) # Train the model with the training data

        predictions = home_model.predict(val_X) # Make the predictions
        mae = mean_absolute_error(val_y, predictions)
        print(f"MAE: {mae}")
        if 0.02 < abs(1 - mae / previous_mae) < 1:
            if mae > 10000:
                previous_mae = mae
                print(f"New MAE: {mae}")
            else:
                break
        else:
            selected_features.remove(feature)
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[13], line 2
#       1 # pydev_debug_cell
# ----> 2 selected_features = []
#       3 y = home_data.SalePrice # Sale prices
#       4 home_model = RandomForestRegressor(random_state=1) # Current ML model
#
# File ~/.local/share/JetBrains/Toolbox/apps/pycharm/plugins/python-ce/helpers/pydev/_pydevd_bundle/pydevd_frame.py:755, in PyDBFrame.trace_dispatch(self, frame, event, arg)
#     753 # if thread has a suspend flag, we suspend with a busy wait
#     754 if info.pydev_state == STATE_SUSPEND:
# --> 755     self.do_wait_suspend(thread, frame, event, arg)
#     756     # No need to reset frame.f_trace to keep the same trace function.
#     757     return self.trace_dispatch
#
# File ~/.local/share/JetBrains/Toolbox/apps/pycharm/plugins/python-ce/helpers/pydev/_pydevd_bundle/pydevd_frame.py:412, in PyDBFrame.do_wait_suspend(self, *args, **kwargs)
#     411 def do_wait_suspend(self, *args, **kwargs):
# --> 412     self._args[0].do_wait_suspend(*args, **kwargs)
#
# File ~/.local/share/JetBrains/Toolbox/apps/pycharm/plugins/python-ce/helpers/pydev/pydevd.py:1196, in PyDB.do_wait_suspend(self, thread, frame, event, arg, send_suspend_message, is_unhandled_exception)
#    1193         from_this_thread.append(frame_id)
#    1195 with self._threads_suspended_single_notification.notify_thread_suspended(thread_id, stop_reason):
# -> 1196     self._do_wait_suspend(thread, frame, event, arg, suspend_type, from_this_thread)
#
# File ~/.local/share/JetBrains/Toolbox/apps/pycharm/plugins/python-ce/helpers/pydev/pydevd.py:1211, in PyDB._do_wait_suspend(self, thread, frame, event, arg, suspend_type, from_this_thread)
#    1208             self._call_mpl_hook()
#    1210         self.process_internal_commands()
# -> 1211         time.sleep(0.01)
#    1213 self.cancel_async_evaluation(get_current_thread_id(thread), str(id(frame)))
#    1215 # process any stepping instructions
#
# KeyboardInterrupt:
